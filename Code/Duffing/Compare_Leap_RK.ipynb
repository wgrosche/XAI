# %%
pip install gala
# Out:
# ...
#   Using cached gala-1.3.tar.gz (2.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached astropy-4.2.1-cp38-cp38-win_amd64.whl (6.2 MB)
# ...
#   Using cached pyerfa-2.0.0-cp38-cp38-win_amd64.whl (366 kB)
# ...
# Failed to build gala
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Anaconda\envs\XAI\python.exe' 'D:\Anaconda\envs\XAI\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\wilke\AppData\Local\Temp\tmp5vpt6a7l'
#        cwd: C:\Users\wilke\AppData\Local\Temp\pip-install-9_f1_npn\gala_dd6e721092c34babb1900ea60ae269fb
#   Complete output (314 lines):
# ...

# %%
import gala
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-a70542098a55> in <module>
# ----> 1 import gala
#
# ModuleNotFoundError: No module named 'gala'

# %%
pip install wheel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cython
# Out:
# ...
#   Using cached Cython-0.29.23-cp38-cp38-win_amd64.whl (1.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
